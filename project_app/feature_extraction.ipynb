# %%
import pandas as pd
import pickle
import numpy as np

# %%
# all data taken here
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df
# we want this features
# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       964    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       964    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       964    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       964    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# ...

# %%
# lets check for null values
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %% [markdown]
# city have lots of missing values

# %%
# here looking at venue we are able to see city names
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %%
# this city names from venue are extracted and fill thus null values
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
# column created
df['city'] = cities

# %%
# now there is no null values
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
# venue is not required to us so we will drop that column
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
# now we will take only thus values where at least 5 matches are played means 600 balls are played
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
# filter condition
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
# to carry out current score
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# C:\Users\Tushar\AppData\Local\Temp\ipykernel_980\4233494361.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# ...

# %%
# thus code is to get over and ball_no columns
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no
# 0    Melbourne              0    0       1
# 1    Melbourne              0    0       2
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled
# 0    Melbourne              0    0       1             1
# ...

# %%
# balls_left column is created
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# ...

# %%
# to wickets left from player_dismissed column
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\Tushar\AppData\Local\Temp\ipykernel_980\2911486542.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
# to get current run rate crr
df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
# to get last five overs run
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# C:\Users\Tushar\AppData\Local\Temp\ipykernel_980\731036983.py:7: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
# column of last_five created
df['last_five'] = last_five

# %%
# to get final score 
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')
# Out:
# C:\Users\Tushar\AppData\Local\Temp\ipykernel_980\286944923.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
# now this is our final_df
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.isnull().sum()
# Out:
# batting_team         0
# bowling_team         0
# city                 0
# current_score        0
# balls_left           0
# wickets_left         0
# crr                  0
# last_five        12024
# runs_x               0
# dtype: int64

# %%
# missing values we will remove
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
# to avoid here we do shuffling
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#       batting_team bowling_team        city  current_score  balls_left  \
# 11532  West Indies        India  Lauderhill             53          50
# 4845     Sri Lanka     Pakistan   Abu Dhabi            117           6
#
#        wickets_left       crr  last_five  runs_x
# 11532             5  4.542857       20.0      95
# 4845              2  6.157895       22.0     124

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38477 entries, 49429 to 28513
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   batting_team   38477 non-null  object
#  1   bowling_team   38477 non-null  object
#  2   city           38477 non-null  object
#  3   current_score  38477 non-null  int64
#  4   balls_left     38477 non-null  int64
#  5   wickets_left   38477 non-null  int32
#  6   crr            38477 non-null  float64
#  7   last_five      38477 non-null  float64
#  8   runs_x         38477 non-null  int64
# dtypes: float64(2), int32(1), int64(3), object(3)
# memory usage: 2.8+ MB

# %% [markdown]
# **we do one hot encoding for object data type**

# %%
final_df = pd.get_dummies(final_df,columns=['batting_team','bowling_team','city'])

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38477 entries, 49429 to 28513
# Data columns (total 61 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   current_score              38477 non-null  int64
#  1   balls_left                 38477 non-null  int64
#  2   wickets_left               38477 non-null  int32
#  3   crr                        38477 non-null  float64
#  4   last_five                  38477 non-null  float64
#  5   runs_x                     38477 non-null  int64
#  6   batting_team_Afghanistan   38477 non-null  uint8
#  7   batting_team_Australia     38477 non-null  uint8
#  8   batting_team_Bangladesh    38477 non-null  uint8
#  9   batting_team_England       38477 non-null  uint8
#  10  batting_team_India         38477 non-null  uint8
#  11  batting_team_New Zealand   38477 non-null  uint8
#  12  batting_team_Pakistan      38477 non-null  uint8
# ...

# %%
# train test split
x = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team bowling_team          city  current_score  balls_left  \
# 37492   West Indies      England      Barbados             76          61
# 15088  South Africa        India  Johannesburg             49          68
# 34886   West Indies  New Zealand    Lauderhill            176           1
# 8253    New Zealand    Sri Lanka      Auckland             38          76
# 33885   West Indies    Sri Lanka       Colombo             24          69
# ...             ...          ...           ...            ...         ...
# 35827   New Zealand      England      Hamilton            112          41
# 46158   New Zealand     Pakistan    Wellington            159          17
# 32079    Bangladesh     Pakistan     Pallekele            134          27
# 34669   West Indies  New Zealand    Lauderhill             43          82
# 15376   West Indies      England        London            137          31
#
#        wickets_left       crr  last_five
# ...

# %% [markdown]
# ### **Linear regression**

# %%
from sklearn.linear_model import LinearRegression # linear regression model imported
from sklearn.metrics import r2_score # to see accuracy of linear model
Linear_regression_model = LinearRegression() # Linear regression instance created
Linear_regression_model.fit(x_train,y_train) # fitting of model


#model evaluation
y_pred_test = Linear_regression_model.predict(x_test)
Linear_regression_accuracy = r2_score(y_test,y_pred_test)
print(f"Linear regression accuracy {Linear_regression_accuracy}")
# Out:
# Linear regression accuracy 0.6894096684696387

# %% [markdown]
# ### **Decision tree**

# %%
from sklearn.tree import DecisionTreeRegressor
Decision_tree_model = DecisionTreeRegressor() # decision tree instance created
Decision_tree_model.fit(x_train,y_train)

#model evaluation
y_pred_test = Decision_tree_model.predict(x_test)
Decision_Tree_accuracy = r2_score(y_test,y_pred_test)
print(f"Decision Tree accuracy  {Decision_Tree_accuracy}")
# Out:
# Decision Tree accuracy  0.9459871570670791

# %% [markdown]
# ### **Random forest**

# %%
from sklearn.ensemble import RandomForestRegressor
Random_forest_model = RandomForestRegressor()
Random_forest_model.fit(x_train,y_train) # fitting of model

#model evaluation
y_pred_test = Random_forest_model.predict(x_test)
Random_Forest_accuracy = r2_score(y_test,y_pred_test)
print(f"Random Forest accuracy {Random_Forest_accuracy}")
# Out:
# Random Forest accuracy 0.9794665510345063

# %% [markdown]
# **Here we are getting more accuracy with Random forest so we will create pickle of that file only**

# %% [markdown]
# ### **Create Pickle**

# %%
with open('Random_forest_model.pkl','wb') as f:
    pickle.dump(Random_forest_model,f)
